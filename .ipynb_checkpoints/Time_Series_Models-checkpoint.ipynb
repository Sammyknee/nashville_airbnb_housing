# %% [markdown]
# # Import Libraries and Data

# %% [markdown]
# In this part of the analysis, we are going to build time series models to see how well we can predict the typical home value in Nashville.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import statsmodels.api as sm
from statsmodels.tsa.seasonal import seasonal_decompose
from statsmodels.tsa.stattools import adfuller
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf
import warnings
warnings.filterwarnings('ignore')
import itertools
from statsmodels.tsa.statespace.sarimax import SARIMAX
from matplotlib.pylab import rcParams

# %%
ts_df = pd.read_csv("cleaned_data/model_data_clean.csv", index_col=0)

# %%
ts_df.head()
# Out:
#                       id       host_id       zipcode   latitude  longitude  \
# 2015-06-01  4.911123e+06  1.847859e+07  37202.099174  36.161913 -86.768430
# 2015-07-01  4.585624e+06  1.588542e+07  37202.203096  36.157222 -86.767316
# 2015-08-01           NaN           NaN           NaN        NaN        NaN
# 2015-09-01           NaN           NaN           NaN        NaN        NaN
# 2015-10-01  5.435875e+06  1.857827e+07  37201.418483  36.156564 -86.767390
#
#             accommodates  bathrooms      beds       price  minimum_nights  \
# 2015-06-01      4.223140   1.450413  2.033058  163.115702        1.545455
# 2015-07-01      4.607430   1.500310  2.308978  202.349226        1.698452
# 2015-08-01           NaN        NaN       NaN         NaN             NaN
# 2015-09-01           NaN        NaN       NaN         NaN             NaN
# 2015-10-01      4.795735   1.528910  2.406161  200.524171        1.747867
#
#             ...  property_type_Condominium  property_type_Guest suite  \
# 2015-06-01  ...                        1.0                        0.0
# 2015-07-01  ...                       33.0                        0.0
# 2015-08-01  ...                        0.0                        0.0
# 2015-09-01  ...                        0.0                        0.0
# 2015-10-01  ...                       54.0                        0.0
#
#             property_type_House  property_type_Other  property_type_Townhouse  \
# 2015-06-01                 78.0                 11.0                      1.0
# 2015-07-01               1048.0                100.0                     18.0
# 2015-08-01                  0.0                  0.0                      0.0
# 2015-09-01                  0.0                  0.0                      0.0
# 2015-10-01               1360.0                130.0                     51.0
#
#             room_type_Hotel room  room_type_Private room  \
# 2015-06-01                   0.0                    39.0
# 2015-07-01                   0.0                   451.0
# 2015-08-01                   0.0                     0.0
# 2015-09-01                   0.0                     0.0
# 2015-10-01                   0.0                   566.0
#
#             room_type_Shared room  inventory  avg_home_value
# 2015-06-01                    3.0        121        198388.0
# 2015-07-01                   18.0       1615        199865.0
# 2015-08-01                    0.0          0        201227.0
# 2015-09-01                    0.0          0        202952.0
# 2015-10-01                   30.0       2110        204617.0
#
# [5 rows x 50 columns]

# %% [markdown]
# # Set Time Series Index

# %%
ts_df.reset_index(inplace=True)
ts_df['index'] = pd.to_datetime(ts_df['index'],format='%Y/%m/%d')
ts_df.set_index('index', inplace=True)
ts_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 69 entries, 2015-06-01 to 2021-02-01
# Data columns (total 50 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   id                                39 non-null     float64
#  1   host_id                           39 non-null     float64
#  2   zipcode                           39 non-null     float64
#  3   latitude                          39 non-null     float64
#  4   longitude                         39 non-null     float64
#  5   accommodates                      39 non-null     float64
#  6   bathrooms                         39 non-null     float64
#  7   beds                              39 non-null     float64
#  8   price                             39 non-null     float64
#  9   minimum_nights                    39 non-null     float64
#  10  maximum_nights                    39 non-null     float64
#  11  availability_30                   39 non-null     float64
#  12  availability_60                   39 non-null     float64
#  13  availability_90                   39 non-null     float64
#  14  number_of_reviews                 39 non-null     float64
#  15  review_scores_rating              39 non-null     float64
#  16  review_scores_accuracy            39 non-null     float64
#  17  review_scores_cleanliness         39 non-null     float64
#  18  review_scores_checkin             39 non-null     float64
#  19  review_scores_communication       39 non-null     float64
#  20  review_scores_location            39 non-null     float64
#  21  review_scores_value               39 non-null     float64
#  22  calculated_host_listings_count    39 non-null     float64
#  23  occ_rate                          39 non-null     float64
#  24  monthly_income                    39 non-null     float64
#  25  host_is_superhost                 69 non-null     int64
#  26  multi_listing_host                69 non-null     int64
#  27  instant_bookable                  69 non-null     int64
#  28  neighborhood_Bellevue             69 non-null     float64
#  29  neighborhood_Donelson             69 non-null     float64
#  30  neighborhood_Downtown             69 non-null     float64
#  31  neighborhood_East_Nashville       69 non-null     float64
#  32  neighborhood_Madison              69 non-null     float64
#  33  neighborhood_Midtown              69 non-null     float64
#  34  neighborhood_North_Nashville      69 non-null     float64
#  35  neighborhood_Parkwood             69 non-null     float64
#  36  neighborhood_South_Nashville      69 non-null     float64
#  37  neighborhood_Southeast_Nashville  69 non-null     float64
#  38  neighborhood_West_Nashville       69 non-null     float64
#  39  neighborhood_Whites_Creek         69 non-null     float64
#  40  property_type_Condominium         69 non-null     float64
#  41  property_type_Guest suite         69 non-null     float64
#  42  property_type_House               69 non-null     float64
#  43  property_type_Other               69 non-null     float64
#  44  property_type_Townhouse           69 non-null     float64
#  45  room_type_Hotel room              69 non-null     float64
#  46  room_type_Private room            69 non-null     float64
#  47  room_type_Shared room             69 non-null     float64
#  48  inventory                         69 non-null     int64
#  49  avg_home_value                    69 non-null     float64
# dtypes: float64(46), int64(4)
# memory usage: 27.5 KB

# %% [markdown]
# # Deal with Missing Time Series Values

# %% [markdown]
# ## Visualize the trend

# %%
ts_df.avg_home_value.plot();

# %% [markdown]
# Appears to be trend without seasonality

# %%
ts_df.inventory.plot();

# %%
ts_df['inventory'] = ts_df['inventory'].replace(0,np.nan)
ts_df.inventory.plot();

# %% [markdown]
# Data appears to be missing throughout 2016 and 2017. Let's see what looking at just 2018 onward looks like.

# %% [markdown]
# ## Focus on Dates after 2018

# %%
post_18_ts_df = ts_df['2018':]

# %%
post_18_ts_df.inventory.plot();

# %% [markdown]
# There are still a handful of missing values. Let's use linear interpolation to fill in these values.

# %%
post_18_ts_df = post_18_ts_df.interpolate()

# %%
post_18_ts_df.dropna(inplace=True)

# %%
post_18_ts_df.inventory.plot();

# %% [markdown]
# ## Interpolate Full Dataset

# %%
ts_df.interpolate(inplace=True)

# %%
ts_df.inventory.plot();

# %% [markdown]
# # Explore Time Series

# %% [markdown]
# ## Decompose Time Series

# %%
# result = seasonal_decompose(ts_df['avg_home_value'], model='add')

# %%
# fig = result.plot()
# fig.set_figheight(6)

# %% [markdown]
# First, we will decompose the time series, assuming it is a series composed of adding the trend, seasonality and residual terms.

# %%
decomposition = seasonal_decompose(ts_df['avg_home_value'], model='add')

# %%
trend = decomposition.trend
seasonal = decomposition.seasonal
residual = decomposition.resid

# Plot decompositions

plt.figure(figsize=(12,8))

plt.subplot(411)
plt.title('Decomposition of Nashville Home Value Time Series')
plt.plot(ts_df['avg_home_value'], label='Original', color='blue')
plt.legend(loc='best')
plt.subplot(412)
plt.plot(trend, label='Trend', color='blue')
plt.legend(loc='best')
plt.subplot(413)
plt.plot(seasonal,label='Seasonality', color='blue')
plt.legend(loc='best')
plt.subplot(414)
plt.plot(residual, label='Residuals', color='blue')
plt.legend(loc='best')

plt.tight_layout()

# %%
residual.dropna(inplace=True)

# %%
stationarity_check(residual)
# Out:
# Test Statistic                 -0.476766
# p-value                         0.896471
# #Lags Used                      3.000000
# Number of Observations Used    53.000000
# dtype: float64

# %% [markdown]
# ## Check Time Series stationarity

# %%
def stationarity_check(ts):
    roll_mean = ts.rolling(window=8, center=False).mean()
    roll_std = ts.rolling(window=8, center=False).std()
    fig = plt.figure(figsize=(8,5))
    plt.plot(ts, color='blue', label='Original')
    plt.plot(roll_mean, color='red', label='Rolling Mean')
    plt.plot(roll_std, color='black', label = 'Rolling Std')
    plt.legend(loc='best')
    plt.title('Rolling Mean & Standard Deviation')
    plt.show(block=False)
    
    dftest = adfuller(ts)
    dfoutput = pd.Series(dftest[0:4], index=['Test Statistic', 'p-value', '#Lags Used', 'Number of Observations Used'])
    return dfoutput

# %%
ts = ts_df['avg_home_value']
stationarity_check(ts)
# Out:
# Test Statistic                  0.624229
# p-value                         0.988198
# #Lags Used                     10.000000
# Number of Observations Used    58.000000
# dtype: float64

# %% [markdown]
# Because the p-value is much greater than 0.05, we cannot reject the null hypothesis that the data is not stationary. This makes sense based on what we've seen in the decomposition plots.

# %% [markdown]
# ## Look at ACF and PACF plots

# %%
# fig,ax= plt.subplots(2,1, figsize=(10,5))
# fig=sm.tsa.graphics.plot_acf(ts, lags=50, ax=ax[0])
# fig=sm.tsa.graphics.plot_pacf(ts, lags=50, ax=ax[1])
# plt.show()

# %%
# plt.figure(figsize=(12,5))
# pd.plotting.autocorrelation_plot(ts);

# %% [markdown]
# The ACF plot shows the correlation between the time series and its lagged values.

# %%
rcParams['figure.figsize'] = 14, 5

plot_acf(ts, lags=50);

# %% [markdown]
# This ACF plot is gradually decreasing as lags increase.

# %% [markdown]
# The PACF plot shows the correlation between the time series and its own lagged values, with lags of intervening observations removed.

# %%
rcParams['figure.figsize'] = 14, 5

plot_pacf(ts, lags=50);

# %% [markdown]
# The PACF plot has a sharp decrease after 2 lags--there is another relationship after 43 lags.

# %% [markdown]
# This pattern of a gradually decreasing ACF plot and sharply decreasing PACF plot is characteristic of an AutoRegressive process.

# %% [markdown]
# # ARMA Time Series Model

# %% [markdown]
# * Come back to*

# %% [markdown]
# ## Differencing

# %%
ts_diff = ts.diff(periods=1)
ts_diff.dropna(inplace=True)

# %%
stationarity_check(ts_diff)
# Out:
# Test Statistic                 -3.483200
# p-value                         0.008429
# #Lags Used                     11.000000
# Number of Observations Used    56.000000
# dtype: float64

# %% [markdown]
# We can now reject the null hypothesis and confirm the data is stationary.

# %% [markdown]
# ## Check ACF and PACF Plots

# %%
rcParams['figure.figsize'] = 14, 5

plot_acf(ts_diff, lags=50);

# %%
rcParams['figure.figsize'] = 14, 5

plot_pacf(ts_diff, lags=50);

# %% [markdown]
# Since the original time series is not stationary, we are going to run SARIMA and SARIMAX models, which do not require stationarity.

# %% [markdown]
# # SARIMA Time Series Model

# %% [markdown]
# ## Set up Data for Modeling

# %%
home_values = ts_df['avg_home_value']

# %%
train_size = int(len(home_values)*.7)
test_size = int(len(home_values)-train_size)
train, test = home_values[0:train_size], home_values[train_size:len(home_values)]
print('Observations: %d' % (len(home_values)))
print('Training Observations: %d' % (len(train)))
print('Testing Observations: %d' % (len(test)))
# Out:
# Observations: 69
# Training Observations: 48
# Testing Observations: 21

# %%
plt.plot(train)
plt.plot(test)
plt.show()

# %% [markdown]
# ## Parameter Selection for the SARIMA Model

# %%
# set seasonal s equal to 12
s=12
# allow p, d and q to take any value from 0 to 1
p = d = q = range(0,2)

# generate all combinations of p,d and q
pdq = list(itertools.product(p, d, q))

# generate all combinations including seasonal combinations
pdqs = [(x[0], x[1], x[2], s) for x in pdq]

# %%
# run grid with parameters above and select best AIC value
ans = []
for comb in pdq:
    for combs in pdqs:
        mod = SARIMAX(train,
                     order=comb,
                     seasonal_order=combs,
                     enforce_stationarity=False,
                     enforce_invertibility=False)
        output = mod.fit()
        ans.append([comb, combs, output.aic])
        print('ARIMA {} x {}12: AIC = {}'.format(comb, combs, output.aic))
# Out:
# ARIMA (0, 0, 0) x (0, 0, 0, 12)12: AIC = 1300.8230609538462
# ARIMA (0, 0, 0) x (0, 0, 1, 12)12: AIC = 1130.706083548577
# ARIMA (0, 0, 0) x (0, 1, 0, 12)12: AIC = 798.9331500871451
# ARIMA (0, 0, 0) x (0, 1, 1, 12)12: AIC = 524.02157038227
# ARIMA (0, 0, 0) x (1, 0, 0, 12)12: AIC = 721.7873083191544
# ARIMA (0, 0, 0) x (1, 0, 1, 12)12: AIC = 1039.0935159228868
# ARIMA (0, 0, 0) x (1, 1, 0, 12)12: AIC = 483.98081615284605
# ARIMA (0, 0, 0) x (1, 1, 1, 12)12: AIC = 437.52610372804617
# ARIMA (0, 0, 1) x (0, 0, 0, 12)12: AIC = 41881.01203245639
# ARIMA (0, 0, 1) x (0, 0, 1, 12)12: AIC = nan
# ARIMA (0, 0, 1) x (0, 1, 0, 12)12: AIC = 758.615438262401
# ARIMA (0, 0, 1) x (0, 1, 1, 12)12: AIC = 499.13524409318745
# ARIMA (0, 0, 1) x (1, 0, 0, 12)12: AIC = 965.6123735074972
# ARIMA (0, 0, 1) x (1, 0, 1, 12)12: AIC = nan
# ARIMA (0, 0, 1) x (1, 1, 0, 12)12: AIC = 529.8899324443589
# ARIMA (0, 0, 1) x (1, 1, 1, 12)12: AIC = 495.3898344439714
# ARIMA (0, 1, 0) x (0, 0, 0, 12)12: AIC = 816.8576537210402
# ARIMA (0, 1, 0) x (0, 0, 1, 12)12: AIC = 1168.4940619567328
# ARIMA (0, 1, 0) x (0, 1, 0, 12)12: AIC = 545.7375126077676
# ARIMA (0, 1, 0) x (0, 1, 1, 12)12: AIC = 361.44059173486824
# ARIMA (0, 1, 0) x (1, 0, 0, 12)12: AIC = 555.3192358512756
# ARIMA (0, 1, 0) x (1, 0, 1, 12)12: AIC = 1349.2480225605962
# ARIMA (0, 1, 0) x (1, 1, 0, 12)12: AIC = 375.22325082306304
# ARIMA (0, 1, 0) x (1, 1, 1, 12)12: AIC = 360.87358442358834
# ARIMA (0, 1, 1) x (0, 0, 0, 12)12: AIC = 747.3959246289796
# ARIMA (0, 1, 1) x (0, 0, 1, 12)12: AIC = 2716.116059980819
# ARIMA (0, 1, 1) x (0, 1, 0, 12)12: AIC = 521.4398244088729
# ARIMA (0, 1, 1) x (0, 1, 1, 12)12: AIC = 325.45686361686194
# ARIMA (0, 1, 1) x (1, 0, 0, 12)12: AIC = 595.8053595107193
# ARIMA (0, 1, 1) x (1, 0, 1, 12)12: AIC = 2722.9691680366386
# ARIMA (0, 1, 1) x (1, 1, 0, 12)12: AIC = 360.4246828444456
# ARIMA (0, 1, 1) x (1, 1, 1, 12)12: AIC = 330.0229935997018
# ARIMA (1, 0, 0) x (0, 0, 0, 12)12: AIC = 737.7054855173117
# ARIMA (1, 0, 0) x (0, 0, 1, 12)12: AIC = 2432.9451828063593
# ARIMA (1, 0, 0) x (0, 1, 0, 12)12: AIC = 559.9624030510188
# ARIMA (1, 0, 0) x (0, 1, 1, 12)12: AIC = 368.80594054193364
# ARIMA (1, 0, 0) x (1, 0, 0, 12)12: AIC = 546.1202146226426
# ARIMA (1, 0, 0) x (1, 0, 1, 12)12: AIC = 2515.809527663518
# ARIMA (1, 0, 0) x (1, 1, 0, 12)12: AIC = 367.05473578512755
# ARIMA (1, 0, 0) x (1, 1, 1, 12)12: AIC = 367.1506286755571
# ARIMA (1, 0, 1) x (0, 0, 0, 12)12: AIC = 703.743110301925
# ARIMA (1, 0, 1) x (0, 0, 1, 12)12: AIC = 2413.8398113375365
# ARIMA (1, 0, 1) x (0, 1, 0, 12)12: AIC = 539.3281842022003
# ARIMA (1, 0, 1) x (0, 1, 1, 12)12: AIC = 340.9680784087615
# ARIMA (1, 0, 1) x (1, 0, 0, 12)12: AIC = 557.9055482898538
# ARIMA (1, 0, 1) x (1, 0, 1, 12)12: AIC = 44362.19942015738
# ARIMA (1, 0, 1) x (1, 1, 0, 12)12: AIC = 355.78118352998797
# ARIMA (1, 0, 1) x (1, 1, 1, 12)12: AIC = 342.4365332619444
# ARIMA (1, 1, 0) x (0, 0, 0, 12)12: AIC = 636.2886893657908
# ARIMA (1, 1, 0) x (0, 0, 1, 12)12: AIC = 1290.2275718002736
# ARIMA (1, 1, 0) x (0, 1, 0, 12)12: AIC = 507.9642685838578
# ARIMA (1, 1, 0) x (0, 1, 1, 12)12: AIC = 325.5738487571905
# ARIMA (1, 1, 0) x (1, 0, 0, 12)12: AIC = 454.380481297431
# ARIMA (1, 1, 0) x (1, 0, 1, 12)12: AIC = 887.2891229411898
# ARIMA (1, 1, 0) x (1, 1, 0, 12)12: AIC = 311.67347045867405
# ARIMA (1, 1, 0) x (1, 1, 1, 12)12: AIC = 313.6562273333195
# ARIMA (1, 1, 1) x (0, 0, 0, 12)12: AIC = 625.1479341390268
# ARIMA (1, 1, 1) x (0, 0, 1, 12)12: AIC = nan
# ARIMA (1, 1, 1) x (0, 1, 0, 12)12: AIC = 495.00834113023217
# ARIMA (1, 1, 1) x (0, 1, 1, 12)12: AIC = 309.41666310012664
# ARIMA (1, 1, 1) x (1, 0, 0, 12)12: AIC = 456.35591703555895
# ARIMA (1, 1, 1) x (1, 0, 1, 12)12: AIC = 2511.6131709403685
# ARIMA (1, 1, 1) x (1, 1, 0, 12)12: AIC = 313.3343285315138
# ARIMA (1, 1, 1) x (1, 1, 1, 12)12: AIC = 300.81188299830546

# %%
ans_df = pd.DataFrame(ans, columns=['pdq','pdqs','aic'])
ans_df.loc[ans_df['aic'].idxmin()]
# Out:
# pdq         (1, 1, 1)
# pdqs    (1, 1, 1, 12)
# aic           300.812
# Name: 63, dtype: object

# %%
order = ans_df.loc[ans_df['aic'].idxmin()][0]
seasonal_order = ans_df.loc[ans_df['aic'].idxmin()][1]

# %% [markdown]
# ## Fit SARIMA Model

# %%
SARIMA_MODEL = SARIMAX(train,
                      order=order,
                      seasonal_order=seasonal_order,
                      enforce_stationarity=False,
                      enforce_invertibility=False)

# %%
sarima_output = SARIMA_MODEL.fit()
sarima_output.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                      SARIMAX Results
# ==========================================================================================
# Dep. Variable:                     avg_home_value   No. Observations:                   48
# Model:             SARIMAX(1, 1, 1)x(1, 1, 1, 12)   Log Likelihood                -145.406
# Date:                            Thu, 08 Apr 2021   AIC                            300.812
# Time:                                    16:13:24   BIC                            306.034
# Sample:                                06-01-2015   HQIC                           301.945
#                                      - 05-01-2019
# Covariance Type:                              opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1          0.9821      0.093     10.534      0.000       0.799       1.165
# ma.L1          0.1519      0.216      0.705      0.481      -0.271       0.575
# ar.S.L12      -0.6322      0.138     -4.582      0.000      -0.903      -0.362
# ma.S.L12      -0.0055      0.054     -0.102      0.919      -0.112       0.101
# sigma2      6.045e+04   3.08e+04      1.965      0.049     145.992    1.21e+05
# ===================================================================================
# Ljung-Box (Q):                       28.00   Jarque-Bera (JB):                 1.68
# Prob(Q):                              0.11   Prob(JB):                         0.43
# Heteroskedasticity (H):               1.49   Skew:                            -0.35
# Prob(H) (two-sided):                  0.61   Kurtosis:                         1.80
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# """

# %% [markdown]
# According to the p-values in our model summary, the moving average portion of the model is not statistically significant for non-seasonal or seasonal. We will try running a model with (1,1,0)(1,1,0,12) as our parameters and see if we get different results.

# %% [markdown]
# ## SARIMA Model 2

# %%
SARIMA_MODEL2 = SARIMAX(train,
                      order=(1, 1, 0),
                      seasonal_order=(1, 1, 0, 12),
                      enforce_stationarity=False,
                      enforce_invertibility=False)

# %%
sarima_output_2 = SARIMA_MODEL2.fit()
sarima_output_2.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                      SARIMAX Results
# ==========================================================================================
# Dep. Variable:                     avg_home_value   No. Observations:                   48
# Model:             SARIMAX(1, 1, 0)x(1, 1, 0, 12)   Log Likelihood                -152.837
# Date:                            Thu, 08 Apr 2021   AIC                            311.673
# Time:                                    16:13:38   BIC                            314.947
# Sample:                                06-01-2015   HQIC                           312.445
#                                      - 05-01-2019
# Covariance Type:                              opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1          0.9900      0.083     11.907      0.000       0.827       1.153
# ar.S.L12      -0.6094      0.134     -4.564      0.000      -0.871      -0.348
# sigma2      6.335e+04   2.72e+04      2.331      0.020    1.01e+04    1.17e+05
# ===================================================================================
# Ljung-Box (Q):                       28.08   Jarque-Bera (JB):                 1.87
# Prob(Q):                              0.14   Prob(JB):                         0.39
# Heteroskedasticity (H):               2.34   Skew:                            -0.34
# Prob(H) (two-sided):                  0.29   Kurtosis:                         1.75
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# """

# %% [markdown]
# Our AIC value is slightly higher in this model, therefore, we will stick with the original SARIMA model.

# %% [markdown]
# ## Run Model Diagnostics

# %%
sarima_output.plot_diagnostics(figsize=(15,9));

# %% [markdown]
# It appears the residuals are normally distributed based on the KDE plot and the qq-plot, although there could be some violations at either tail.
# The residuals appear to have white noise and are not showing signs of seasonality. The residuals are also not highly correlated with themselves based on the autocorrelation plot.

# %% [markdown]
# ## One-Step Ahead Forecasting

# %%
pred = sarima_output.get_prediction(start=pd.to_datetime('2018-01-01'), end=pd.to_datetime('2021-02-01'), dynamic=False)
pred_conf = pred.conf_int()

# %%
rcParams['figure.figsize'] = 15, 6

ax = home_values.plot(label='observed')

pred.predicted_mean.plot(ax=ax, label='One-step ahead forecast')

# plot confidence intervals
ax.fill_between(pred_conf.index,
               pred_conf.iloc[:,0],
               pred_conf.iloc[:,1], color='g', alpha=.25)

ax.set_xlabel('Date')
ax.set_ylabel('Avg Home Value')
plt.legend()
plt.show()

# %%
home_values_forecasted = pred.predicted_mean
home_values_true = home_values['2018':]
rmse = np.sqrt(((home_values_forecasted - home_values_true)**2).mean())
print(rmse)
# Out:
# 9540.536091137623

# %% [markdown]
# ## Dynamic Forecast

# %% [markdown]
# Dynamic forecasting uses values from previously forecasting time points to make predictions.

# %%
pred_dynamic = sarima_output.get_prediction(start=pd.to_datetime('2018-01-01'), end=pd.to_datetime('2021-02-01'), 
                                     dynamic=True, full_results=True)
pred_dynamic_conf = pred_dynamic.conf_int()

# %%
rcParams['figure.figsize'] = 15, 6

ax = home_values.plot(label='observed')

pred_dynamic.predicted_mean.plot(ax=ax, label='Dynamic forecast')

# plot confidence intervals
ax.fill_between(pred_dynamic_conf.index,
               pred_dynamic_conf.iloc[:,0],
               pred_dynamic_conf.iloc[:,1], color='g',alpha=0.25)

ax.fill_betweenx(ax.get_ylim(), pd.to_datetime('2018-01-01'), home_values_forecasted.index[-1], alpha=.1, zorder=-1)
ax.set_xlabel('Date')
ax.set_ylabel('Avg Home Value')
plt.legend()
plt.show()

# %%
dyn_home_values_forecasted = pred_dynamic.predicted_mean
home_values_true = home_values['2018':]
rmse = np.sqrt(((dyn_home_values_forecasted - home_values_true)**2).mean())
print(rmse)
# Out:
# 19970.04381836502

# %% [markdown]
# Much higher RMSE using a dynamic model.

# %% [markdown]
# ## Predicting Future Values

# %%
# prediction = sarima_output.get_forecast(steps=43)
# pred_conf = prediction.conf_int()

# %%
forecast = sarima_output.get_prediction(start=pd.to_datetime('2018-01-01'), end=pd.to_datetime('2024-01-01'), 
                                     dynamic=True, full_results=True)
pred_conf = forecast.conf_int()

# %%
rcParams['figure.figsize'] = 15, 4
ax = home_values.plot(label='observed')
forecast.predicted_mean.plot(ax=ax, label='Forecast')
ax.fill_between(pred_conf.index,
               pred_conf.iloc[:,0],
               pred_conf.iloc[:,1], color='G', alpha=.25)
ax.set_xlabel('Date')
ax.set_ylabel('Avg Home Value')
plt.legend()
plt.show()

# %%
forecast.predicted_mean
# Out:
# 2018-01-01    256782.647043
# 2018-02-01    258849.167517
# 2018-03-01    261035.271930
# 2018-04-01    263227.967106
# 2018-05-01    265250.383318
#                   ...
# 2023-09-01    408267.238434
# 2023-10-01    410454.845874
# 2023-11-01    412692.835181
# 2023-12-01    415064.538509
# 2024-01-01    417314.441867
# Freq: MS, Length: 73, dtype: float64

# %% [markdown]
# # SARIMAX Time Series Model

# %% [markdown]
# ## Parameter Selection for SARIMAX Model

# %% [markdown]
# For our exogenous parameters in our SARIMAX model, we will use the most important features selected from our regression model.

# %%
final_reg_df = pd.read_csv("cleaned_data/final_reg_features.csv", index_col=0)

# %%
features = list(final_reg_df.columns)

# %%
final_time_series_df = ts_df[features]
post_18_final_time_series_df = post_18_ts_df[features]

# %%
final_time_series_df
# Out:
#             avg_home_value      beds  number_of_reviews  host_is_superhost  \
# index
# 2015-06-01        198388.0  2.033058          17.206612                 23
# 2015-07-01        199865.0  2.308978          16.536223                286
# 2015-08-01        201227.0  2.341373          16.929362                  0
# 2015-09-01        202952.0  2.373767          17.322501                  0
# 2015-10-01        204617.0  2.406161          17.715640                434
# ...                    ...       ...                ...                ...
# 2020-10-01        298809.0  3.715442          53.884558               3533
# 2020-11-01        301461.0  3.692683          54.217325               3429
# 2020-12-01        304539.0  3.645701          53.611572               3495
# 2021-01-01        307585.0  3.651761          54.542506               3497
# 2021-02-01        310812.0  3.667916          54.167183               3515
#
#             neighborhood_North_Nashville
# index
# 2015-06-01                           6.0
# 2015-07-01                          49.0
# 2015-08-01                           0.0
# 2015-09-01                           0.0
# 2015-10-01                          76.0
# ...                                  ...
# 2020-10-01                         673.0
# 2020-11-01                         689.0
# 2020-12-01                         680.0
# 2021-01-01                         682.0
# 2021-02-01                         694.0
#
# [69 rows x 5 columns]

# %%
home_values = final_time_series_df['avg_home_value']
exog = final_time_series_df.drop('avg_home_value', axis=1)

# %%
train_size = int(len(home_values)*.7)
train, test = home_values[0:train_size], home_values[train_size:len(home_values)]
train_exog, test_exog = exog[0:train_size], exog[train_size:len(home_values)]
print('Observations: %d' % (len(home_values)))
print('Training Observations: %d' % (len(train)))
print('Testing Observations: %d' % (len(test)))
# Out:
# Observations: 69
# Training Observations: 48
# Testing Observations: 21

# %%
ans = []
for comb in pdq:
    for combs in pdqs:
        mod = SARIMAX(train, train_exog,
                     order=comb,
                     seasonal_order=combs,
                     enforce_stationarity=False,
                     enforce_invertibility=False)
        output = mod.fit()
        ans.append([comb, combs, output.aic])
        print('ARIMA {} x {}12: AIC = {}'.format(comb, combs, output.aic))
# Out:
# ARIMA (0, 0, 0) x (0, 0, 0, 12)12: AIC = 868.5652197532814
# ARIMA (0, 0, 0) x (0, 0, 1, 12)12: AIC = 1382.3985930362328
# ARIMA (0, 0, 0) x (0, 1, 0, 12)12: AIC = 660.5888940139937
# ARIMA (0, 0, 0) x (0, 1, 1, 12)12: AIC = 443.95854698660617
# ARIMA (0, 0, 0) x (1, 0, 0, 12)12: AIC = 674.6976385963668
# ARIMA (0, 0, 0) x (1, 0, 1, 12)12: AIC = 1479.6347273670347
# ARIMA (0, 0, 0) x (1, 1, 0, 12)12: AIC = 457.5719974730623
# ARIMA (0, 0, 0) x (1, 1, 1, 12)12: AIC = 437.4974321685482
# ARIMA (0, 0, 1) x (0, 0, 0, 12)12: AIC = 832.4989908530738
# ARIMA (0, 0, 1) x (0, 0, 1, 12)12: AIC = 2852.3172460268815
# ARIMA (0, 0, 1) x (0, 1, 0, 12)12: AIC = 641.1889231450348
# ARIMA (0, 0, 1) x (0, 1, 1, 12)12: AIC = 414.59834101148
# ARIMA (0, 0, 1) x (1, 0, 0, 12)12: AIC = 662.1838356744257
# ARIMA (0, 0, 1) x (1, 0, 1, 12)12: AIC = 5358.110458971895
# ARIMA (0, 0, 1) x (1, 1, 0, 12)12: AIC = 454.32499232707835
# ARIMA (0, 0, 1) x (1, 1, 1, 12)12: AIC = 413.7058044553173
# ARIMA (0, 1, 0) x (0, 0, 0, 12)12: AIC = 766.2051943343965
# ARIMA (0, 1, 0) x (0, 0, 1, 12)12: AIC = 781.162023725384
# ARIMA (0, 1, 0) x (0, 1, 0, 12)12: AIC = 552.5136841614658
# ARIMA (0, 1, 0) x (0, 1, 1, 12)12: AIC = 368.45596813695994
# ARIMA (0, 1, 0) x (1, 0, 0, 12)12: AIC = 578.948746802524
# ARIMA (0, 1, 0) x (1, 0, 1, 12)12: AIC = 2763.487371151289
# ARIMA (0, 1, 0) x (1, 1, 0, 12)12: AIC = 382.34172324276955
# ARIMA (0, 1, 0) x (1, 1, 1, 12)12: AIC = 367.37095588858455
# ARIMA (0, 1, 1) x (0, 0, 0, 12)12: AIC = 742.4093968189346
# ARIMA (0, 1, 1) x (0, 0, 1, 12)12: AIC = 2813.351922829832
# ARIMA (0, 1, 1) x (0, 1, 0, 12)12: AIC = 528.1427505695465
# ARIMA (0, 1, 1) x (0, 1, 1, 12)12: AIC = 331.2166779690828
# ARIMA (0, 1, 1) x (1, 0, 0, 12)12: AIC = 588.6624199477274
# ARIMA (0, 1, 1) x (1, 0, 1, 12)12: AIC = 18295.917544976404
# ARIMA (0, 1, 1) x (1, 1, 0, 12)12: AIC = 364.16750896663274
# ARIMA (0, 1, 1) x (1, 1, 1, 12)12: AIC = 336.5415982041143
# ARIMA (1, 0, 0) x (0, 0, 0, 12)12: AIC = 859.1246709313357
# ARIMA (1, 0, 0) x (0, 0, 1, 12)12: AIC = 1539.1551161672019
# ARIMA (1, 0, 0) x (0, 1, 0, 12)12: AIC = 628.0619267096397
# ARIMA (1, 0, 0) x (0, 1, 1, 12)12: AIC = 401.4177505182306
# ARIMA (1, 0, 0) x (1, 0, 0, 12)12: AIC = 639.6754817557297
# ARIMA (1, 0, 0) x (1, 0, 1, 12)12: AIC = 2776.4553367282892
# ARIMA (1, 0, 0) x (1, 1, 0, 12)12: AIC = 404.94196629179083
# ARIMA (1, 0, 0) x (1, 1, 1, 12)12: AIC = 427.6983816918441
# ARIMA (1, 0, 1) x (0, 0, 0, 12)12: AIC = 825.0106697458212
# ARIMA (1, 0, 1) x (0, 0, 1, 12)12: AIC = 151974917796.89322
# ARIMA (1, 0, 1) x (0, 1, 0, 12)12: AIC = 590.9453323421501
# ARIMA (1, 0, 1) x (0, 1, 1, 12)12: AIC = 402.63136692906403
# ARIMA (1, 0, 1) x (1, 0, 0, 12)12: AIC = 641.3159866205306
# ARIMA (1, 0, 1) x (1, 0, 1, 12)12: AIC = 2692.2371154770303
# ARIMA (1, 0, 1) x (1, 1, 0, 12)12: AIC = 437.2054074349457
# ARIMA (1, 0, 1) x (1, 1, 1, 12)12: AIC = 410.8008155589407
# ARIMA (1, 1, 0) x (0, 0, 0, 12)12: AIC = 725.2921254699678
# ARIMA (1, 1, 0) x (0, 0, 1, 12)12: AIC = 1090.1572689231873
# ARIMA (1, 1, 0) x (0, 1, 0, 12)12: AIC = 511.94773899149186
# ARIMA (1, 1, 0) x (0, 1, 1, 12)12: AIC = 328.7706316158399
# ARIMA (1, 1, 0) x (1, 0, 0, 12)12: AIC = 566.7800703884996
# ARIMA (1, 1, 0) x (1, 0, 1, 12)12: AIC = 2744.1234703221385
# ARIMA (1, 1, 0) x (1, 1, 0, 12)12: AIC = 315.8167317664487
# ARIMA (1, 1, 0) x (1, 1, 1, 12)12: AIC = 321.58006119301103
# ARIMA (1, 1, 1) x (0, 0, 0, 12)12: AIC = 682.7322171965351
# ARIMA (1, 1, 1) x (0, 0, 1, 12)12: AIC = 2659.1027048368733
# ARIMA (1, 1, 1) x (0, 1, 0, 12)12: AIC = 499.59029748238254
# ARIMA (1, 1, 1) x (0, 1, 1, 12)12: AIC = 305.4040473838604
# ARIMA (1, 1, 1) x (1, 0, 0, 12)12: AIC = 571.6224277200624
# ARIMA (1, 1, 1) x (1, 0, 1, 12)12: AIC = 3044.393319619132
# ARIMA (1, 1, 1) x (1, 1, 0, 12)12: AIC = 321.41579944029775
# ARIMA (1, 1, 1) x (1, 1, 1, 12)12: AIC = 315.0191229887959

# %%
ans_df = pd.DataFrame(ans, columns=['pdq','pdqs','aic'])
ans_df.loc[ans_df['aic'].idxmin()]
# Out:
# pdq         (1, 1, 1)
# pdqs    (0, 1, 1, 12)
# aic           305.404
# Name: 59, dtype: object

# %%
order = ans_df.loc[ans_df['aic'].idxmin()][0]
seasonal_order = ans_df.loc[ans_df['aic'].idxmin()][1]

# %% [markdown]
# ## Fit SARIMAX Model

# %%
SARIMAX_MODEL = SARIMAX(train, train_exog,
                      order=order,
                      seasonal_order=seasonal_order,
                      enforce_stationarity=False,
                      enforce_invertibility=False)

# %%
sarimax_output = SARIMAX_MODEL.fit()
sarimax_output.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                      SARIMAX Results
# ==========================================================================================
# Dep. Variable:                     avg_home_value   No. Observations:                   48
# Model:             SARIMAX(1, 1, 1)x(0, 1, 1, 12)   Log Likelihood                -144.702
# Date:                            Thu, 08 Apr 2021   AIC                            305.404
# Time:                                    14:56:41   BIC                            313.760
# Sample:                                06-01-2015   HQIC                           307.218
#                                      - 05-01-2019
# Covariance Type:                              opg
# ================================================================================================
#                                    coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------
# beds                           473.0373   1037.150      0.456      0.648   -1559.740    2505.815
# number_of_reviews              -42.7573     61.692     -0.693      0.488    -163.670      78.156
# host_is_superhost               -0.1333      0.327     -0.407      0.684      -0.775       0.508
# neighborhood_North_Nashville     0.9491      1.581      0.600      0.548      -2.150       4.049
# ar.L1                            1.0057      0.100     10.025      0.000       0.809       1.202
# ma.L1                            0.5200      0.221      2.349      0.019       0.086       0.954
# ma.S.L12                        -0.6161      0.233     -2.642      0.008      -1.073      -0.159
# sigma2                        3.768e+04   1.99e+04      1.891      0.059   -1383.798    7.67e+04
# ===================================================================================
# Ljung-Box (Q):                       30.94   Jarque-Bera (JB):                 1.26
# Prob(Q):                              0.06   Prob(JB):                         0.53
# Heteroskedasticity (H):               0.78   Skew:                            -0.26
# Prob(H) (two-sided):                  0.75   Kurtosis:                         1.92
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# """

# %% [markdown]
# The AIC value for the SARIMAX model is slightly higher than the SARIMA model, and our exogenous factors do not have significant p-values.

# %%
sarimax_output.plot_diagnostics(figsize=(15,9));

# %% [markdown]
# ## Make Predictions

# %%
pred = sarimax_output.get_prediction(start=pd.to_datetime('2018-01-01'), end=pd.to_datetime('2021-02-01'), dynamic=False,
                            exog=test_exog)
pred_conf = pred.conf_int()

# %%
rcParams['figure.figsize'] = 15, 6

ax = home_values.plot(label='observed')

pred.predicted_mean.plot(ax=ax, label='One-step ahead forecast')

# plot confidence intervals
ax.fill_between(pred_conf.index,
               pred_conf.iloc[:,0],
               pred_conf.iloc[:,1], color='g', alpha=.25)

ax.set_xlabel('Date')
ax.set_ylabel('Avg Home Value')
plt.legend()
plt.show()

# %%
home_values_forecasted = pred.predicted_mean
home_values_true = home_values['2018':]
rmse = np.sqrt(((home_values_forecasted - home_values_true)**2).mean())
print(rmse)
# Out:
# 7413.765251703322

# %% [markdown]
# The SARIMAX model has higher RMSE than the SARIMA model, 7,413 compared to 4,914.

# %% [markdown]
# ## Dynamic Forecast

# %%
pred_dynamic = sarimax_output.get_prediction(start=pd.to_datetime('2018-01-01'), end=pd.to_datetime('2021-02-01'),
                                     dynamic=True, full_results=True, exog=test_exog)
pred_dynamic_conf = pred_dynamic.conf_int()

# %%
rcParams['figure.figsize'] = 15, 6

ax = home_values.plot(label='observed')

pred_dynamic.predicted_mean.plot(ax=ax, label='Dynamic forecast')

# plot confidence intervals
ax.fill_between(pred_dynamic_conf.index,
               pred_dynamic_conf.iloc[:,0],
               pred_dynamic_conf.iloc[:,1], color='g',alpha=0.25)

ax.fill_betweenx(ax.get_ylim(), pd.to_datetime('2018-01-01'), home_values_forecasted.index[-1], alpha=.1, zorder=-1)
ax.set_xlabel('Date')
ax.set_ylabel('Avg Home Value')
plt.legend()
plt.show()

# %%
dyn_home_values_forecasted = pred_dynamic.predicted_mean
home_values_true = home_values['2018':]
rmse = np.sqrt(((dyn_home_values_forecasted - home_values_true)**2).mean())
print(rmse)
# Out:
# 42030.25036922929

# %% [markdown]
# There is a much higher RMSE using a dynamic model. The RMSE is also much higher than in our SARIMA model. We can conclude that the SARIMA model makes better predictions.
